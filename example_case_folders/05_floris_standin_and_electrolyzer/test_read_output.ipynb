# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Read the output file
df = pd.read_csv("hercules_output_control.csv", index_col=False)
df.head()
# Out:
#     dt  hercules_comms.amr_wind.wind_farm_0.num_turbines  \
# 0  0.5                                                 2
# 1  0.5                                                 2
# 2  0.5                                                 2
# 3  0.5                                                 2
# 4  0.5                                                 2
#
#    hercules_comms.amr_wind.wind_farm_0.rotor_diameter  \
# 0                                              126.0
# 1                                              126.0
# 2                                              126.0
# 3                                              126.0
# 4                                              126.0
#
#    hercules_comms.amr_wind.wind_farm_0.turbine_powers.000  \
# 0                                        2843.004700
# 1                                        4264.507050
# 2                                        4975.258224
# 3                                        5330.633812
# 4                                        5508.321606
#
#    hercules_comms.amr_wind.wind_farm_0.turbine_powers.001  \
# 0                                        1314.059412
# 1                                        1971.089119
# 2                                        2299.603972
# 3                                        2463.861398
# 4                                        2545.990112
#
#    hercules_comms.amr_wind.wind_farm_0.turbine_wind_directions.000  \
# 0                                              270.0
# 1                                              270.0
# 2                                              270.0
# 3                                              270.0
# 4                                              270.0
#
#    hercules_comms.amr_wind.wind_farm_0.turbine_wind_directions.001  \
# 0                                              270.0
# 1                                              270.0
# 2                                              270.0
# 3                                              270.0
# 4                                              270.0
#
#    hercules_comms.amr_wind.wind_farm_0.wind_direction  \
# 0                                              270.0
# 1                                              270.0
# 2                                              270.0
# 3                                              270.0
# 4                                              270.0
#
#    hercules_comms.amr_wind.wind_farm_0.sim_time_s_amr_wind  \
# 0                                                0.5
# 1                                                1.0
# 2                                                1.5
# 3                                                2.0
# 4                                                2.5
#
#    hercules_comms.amr_wind.wind_farm_0.wind_farm_power  ...  \
# 0                                        4157.064112    ...
# 1                                        6235.596168    ...
# 2                                        7274.862196    ...
# 3                                        7794.495210    ...
# 4                                        8054.311717    ...
#
#    py_sims.electrolyzer_stack_0.electrolyzer.dt  \
# 0                                           0.5
# 1                                           0.5
# 2                                           0.5
# 3                                           0.5
# 4                                           0.5
#
#    py_sims.electrolyzer_stack_0.initial_conditions.power_available_kw  \
# 0                                               3000
# 1                                               3000
# 2                                               3000
# 3                                               3000
# 4                                               3000
#
#    py_sims.electrolyzer_stack_0.outputs.H2_output  \
# 0                                        0.000717
# 1                                        0.000651
# 2                                        0.001192
# 3                                        0.001775
# 4                                        0.002303
#
#    py_sims.electrolyzer_stack_0.outputs.stacks_on  \
# 0                                               7
# 1                                               7
# 2                                               7
# 3                                               7
# 4                                               7
#
#    py_sims.inputs.available_power  py_sims.inputs.sim_time_s  \
# 0                     4157.064112                        0.5
# 1                     6235.596168                        1.0
# 2                     7274.862196                        1.5
# 3                     7794.495210                        2.0
# 4                     8054.311717                        2.5
#
#    controller.num_turbines  controller.initial_conditions.yaw  time  \
# 0                        2                              270.0   0.5
# 1                        2                              270.0   1.0
# 2                        2                              270.0   1.5
# 3                        2                              270.0   2.0
# 4                        2                              270.0   2.5
#
#                    clock_time
# 0  2024-11-21 14:44:28.714905
# 1  2024-11-21 14:44:28.740122
# 2  2024-11-21 14:44:28.764875
# 3  2024-11-21 14:44:28.784835
# 4  2024-11-21 14:44:28.806847
#
# [5 rows x 63 columns]

# %%
df.columns
# Out:
# Index(['dt', 'hercules_comms.amr_wind.wind_farm_0.num_turbines',
#        'hercules_comms.amr_wind.wind_farm_0.rotor_diameter',
#        'hercules_comms.amr_wind.wind_farm_0.turbine_powers.000',
#        'hercules_comms.amr_wind.wind_farm_0.turbine_powers.001',
#        'hercules_comms.amr_wind.wind_farm_0.turbine_wind_directions.000',
#        'hercules_comms.amr_wind.wind_farm_0.turbine_wind_directions.001',
#        'hercules_comms.amr_wind.wind_farm_0.wind_direction',
#        'hercules_comms.amr_wind.wind_farm_0.sim_time_s_amr_wind',
#        'hercules_comms.amr_wind.wind_farm_0.wind_farm_power',
#        'hercules_comms.amr_wind.wind_farm_0.wind_speed',
#        'hercules_comms.amr_wind.wind_farm_0.turbine_yaw_angles.000',
#        'hercules_comms.amr_wind.wind_farm_0.turbine_yaw_angles.001',
#        'hercules_comms.amr_wind.wind_farm_0.turbine_power_setpoints.000',
#        'hercules_comms.amr_wind.wind_farm_0.turbine_power_setpoints.001',
#        'hercules_comms.helics.config.use_dash_frontend',
#        'hercules_comms.helics.config.KAFKA',
#        'hercules_comms.helics.config.helics.helicsport',
#        'hercules_comms.helics.config.helics.deltat',
#        'hercules_comms.helics.config.publication_interval',
#        'hercules_comms.helics.config.endpoint_interval',
#        'hercules_comms.helics.config.starttime',
#        'hercules_comms.helics.config.stoptime',
#        'py_sims.electrolyzer_stack_0.general.verbose',
#        'py_sims.electrolyzer_stack_0.electrolyzer.initialize',
#        'py_sims.electrolyzer_stack_0.electrolyzer.initial_power_kW',
#        'py_sims.electrolyzer_stack_0.electrolyzer.supervisor.n_stacks',
#        'py_sims.electrolyzer_stack_0.electrolyzer.stack.cell_area',
#        'py_sims.electrolyzer_stack_0.electrolyzer.stack.max_current',
#        'py_sims.electrolyzer_stack_0.electrolyzer.stack.temperature',
#        'py_sims.electrolyzer_stack_0.electrolyzer.stack.n_cells',
#        'py_sims.electrolyzer_stack_0.electrolyzer.stack.min_power',
#        'py_sims.electrolyzer_stack_0.electrolyzer.stack.stack_rating_kW',
#        'py_sims.electrolyzer_stack_0.electrolyzer.stack.include_degradation_penalty',
#        'py_sims.electrolyzer_stack_0.electrolyzer.stack.dt',
#        'py_sims.electrolyzer_stack_0.electrolyzer.stack.degradation.PEM_params.rate_steady',
#        'py_sims.electrolyzer_stack_0.electrolyzer.stack.degradation.PEM_params.rate_fatigue',
#        'py_sims.electrolyzer_stack_0.electrolyzer.stack.degradation.PEM_params.rate_onoff',
#        'py_sims.electrolyzer_stack_0.electrolyzer.stack.cell_params.PEM_params.cell_area',
#        'py_sims.electrolyzer_stack_0.electrolyzer.stack.cell_params.PEM_params.turndown_ratio',
#        'py_sims.electrolyzer_stack_0.electrolyzer.stack.cell_params.PEM_params.max_current_density',
#        'py_sims.electrolyzer_stack_0.electrolyzer.controller.n_stacks',
#        'py_sims.electrolyzer_stack_0.electrolyzer.controller.policy.eager_on',
#        'py_sims.electrolyzer_stack_0.electrolyzer.controller.policy.eager_off',
#        'py_sims.electrolyzer_stack_0.electrolyzer.controller.policy.sequential',
#        'py_sims.electrolyzer_stack_0.electrolyzer.controller.policy.even_dist',
#        'py_sims.electrolyzer_stack_0.electrolyzer.controller.policy.baseline',
#        'py_sims.electrolyzer_stack_0.electrolyzer.cell_params.PEM_params.cell_area',
#        'py_sims.electrolyzer_stack_0.electrolyzer.cell_params.PEM_params.turndown_ratio',
#        'py_sims.electrolyzer_stack_0.electrolyzer.cell_params.PEM_params.max_current_density',
#        'py_sims.electrolyzer_stack_0.electrolyzer.degradation.PEM_params.rate_steady',
#        'py_sims.electrolyzer_stack_0.electrolyzer.degradation.PEM_params.rate_fatigue',
#        'py_sims.electrolyzer_stack_0.electrolyzer.degradation.PEM_params.rate_onoff',
#        'py_sims.electrolyzer_stack_0.electrolyzer.dt',
#        'py_sims.electrolyzer_stack_0.initial_conditions.power_available_kw',
#        'py_sims.electrolyzer_stack_0.outputs.H2_output',
#        'py_sims.electrolyzer_stack_0.outputs.stacks_on',
#        'py_sims.inputs.available_power', 'py_sims.inputs.sim_time_s',
#        'controller.num_turbines', 'controller.initial_conditions.yaw', 'time',
#        'clock_time'],
#       dtype='object')

# %%
plt.figure()
time = df["hercules_comms.amr_wind.wind_farm_0.sim_time_s_amr_wind"]
plt.plot(time, df["hercules_comms.amr_wind.wind_farm_0.turbine_powers.000"], label="WT000")
plt.plot(time, df["hercules_comms.amr_wind.wind_farm_0.turbine_powers.001"], label="WT001")
plt.plot(time, df["py_sims.inputs.available_power"], label="available power")
plt.ylabel("Power [kW]")
plt.xlabel("Time")
plt.legend()

# %%
plt.figure()
plt.plot(time, df["py_sims.electrolyzer_stack_0.outputs.H2_output"], label="H2 Output")
# plt.plot(time, df["hercules_comms.amr_wind.wind_farm_0.turbine_powers.001"], label="WT001")
# plt.plot(time, df["py_sims.inputs.available_power"], label="available power")
plt.ylabel("H2 flowrate [kg/s]")
plt.xlabel("Time")
plt.legend()


print("Number of stacks operating:",df["py_sims.electrolyzer_stack_0.outputs.stacks_on"].iloc[-1])
# Out:
# Number of stacks operating: 7
