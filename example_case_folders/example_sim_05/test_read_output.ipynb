# %%
import pandas as pd

# %%
# Read the output file
df = pd.read_csv('emu_output.csv', index_col=False)
df.head()
# Out:
# /var/folders/zl/d69s6z796rs4fw08fnxrl0qxydms74/T/ipykernel_70478/2608809406.py:2: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   df = pd.read_csv('emu_output.csv', index_col=False)
#           name         description   dt emu_comms.amr_wind.wind_farm_0.type  \
# 0  example_000  Just a solar plant  0.5                      amr_wind_local
# 1  example_000  Just a solar plant  0.5                      amr_wind_local
# 2  example_000  Just a solar plant  0.5                      amr_wind_local
# 3  example_000  Just a solar plant  0.5                      amr_wind_local
# 4  example_000  Just a solar plant  0.5                      amr_wind_local
#
#   emu_comms.amr_wind.wind_farm_0.amr_wind_input_file  \
# 0                                      amr_input.inp
# 1                                      amr_input.inp
# 2                                      amr_input.inp
# ...
